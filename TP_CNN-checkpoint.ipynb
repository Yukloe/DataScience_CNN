# %% [markdown]
# # Convolutional Neural Networks for Handwritten Digits Recognition
#
# This exercise will cover practical aspects for implementing convolutional neural networks (CNN)
#
# **Objectives**:
#
# -  Using TensorFlow, you will build, from scratch, a CNN to classify handwritten digits.
#
#
# # 1. Packages:
# 1.  [numpy](www.numpy.org) library used for numerical computing with Python.
# 2.  [matplotlib](www.matplotlib.org) to create graphs and show images in python.
# 3.  [Tensorflow](www.tensorflow.org) machine learning platform. This framework makes it easy to express high-level abstractions to build end-to-end deep neural networks (From data preparation to Model deployment)
# 4. [sklearn](https://scikit-learn.org) open source data analysis library, include machine learning algorithms for classification, clustering, regression...etc
# 5. [random]() is a Python module which is used to generate random numbers.
#
# ---

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist#, fashion_mnist
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPool2D, Flatten, Dense, Activation, Dropout
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, TensorBoard

from sklearn.model_selection import train_test_split
from random import sample
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\hugop\Desktop\Cours\Année 5\Modelisation\TDP\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # 2.  MNIST Dataset
#
# MNIST handwritten digits dataset already exist on TensorFlow. Load these images using load_data() function from mnist module, which return train and test sets (x_train, y_train), (x_test, y_test).
#
# You have to display the properties of the dataset informations :
#
# 1. Number of training and testing images
# 2. Number of classes
# 3. Image size

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Using the "train_test_split" sklearn function in order to split the train dataset into train/validation subsets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42 ,shuffle=True)

num_classes = 10

print("Number of train images", len(x_train))
print("Number of val images", len(x_val))
print("Number of test images", len(x_test))
print("Number of classes", num_classes)
print("Image size", x_train.shape[1:])
# Out:
# Number of train images 48000
# Number of val images 12000
# Number of test images 10000
# Number of classes 10
# Image size (28, 28)

# %% [markdown]
# #  Data visualization
#
# Dispaly one image per class from the training or the testing datasets.

# %%
images = []
labels = []

for i, y in enumerate(y_test):
    if y in labels:
        continue
    
    labels.append(y)
    images.append(x_test[i])


fig = plt.figure(figsize = (12, 5))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, i+1)
    img = images[i]
    lbl = labels[i]
    plt.imshow(img, cmap='gray')

plt.show()

# %% [markdown]
# # Data Preprocessing
#
# Images are represented in 8-bits integer in range [0-255].
#
# The preprocessing you need to introduce is as follows:
# *   Normalizing the pixel values range from [0-255] integer to [0-1] float
# *   TensorFlow models support 3D image only as input. In our case, we have images with dimensions (H, W). Hence, we need to add a new dimension for each sample in order to have the grayscale one channel shape (H, W, 1) instead of (H, W).
# *   Make sure that the axis is added successfully by displaying the train and test shapes. It should have the following format : (NumOfImages, H, W, 1)

# %%
x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0


x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
x_val = np.expand_dims(x_val, -1)

print("new train-set size:", x_train.shape)
print("new val-set size:", x_val.shape)
print("new test-set size:", x_test.shape)
# Out:
# new train-set size: (48000, 28, 28, 1)
# new val-set size: (12000, 28, 28, 1)
# new test-set size: (10000, 28, 28, 1)

# %% [markdown]
# # 3. Hyperparameters
#
# In this cell, we set the hyperparameters:
#
# - batch_size: is the number of samples processed before performing one update
#
# - epochs: The number of training iteration
#
# - Learning_rate: Control how fast we make updates on the weights during the training process
#
# - l2_reg (L2 regularization): Is the L2 regularizer used for penalizing the output loss

# %%
batch_size = 128
epochs = 20
learning_rate = 0.1
l2_reg_rate = 1e-4 # Replace L2 regularizer by a value > 0 for example 1e-4, otherwise it is disabled
dropout_rate = 0

# %% [markdown]
# # 4. Building the CNN model
#
# LeNet-5 [1] architecture is defined below. It contains two Convloutional layers:
#
# - Convolutional_layer = (Conv2D-ReLU-MaxPool2D) x 2.
#
# - The classification part contains two Dense layers and the output layer:
#
#     - Dense layer = (Dense-ReLU)
#     - Output layer = (Dense-Softmax)
#
# **References**
#
# [1]: Lecun Y, Bottou L, Bengio Y, et al. "Gradient-based learning applied to document recognition,". Proceedings of the IEEE, 1998, 86(11): 2278--2324
#
# ![Alt text](LeNet5.png)

# %%
def LeNet5(l2_reg, dropout):
    model = Sequential()
    model.add(InputLayer(input_shape = (28, 28, 1))) # you can use x_train.shape[1:] instead of (28, 28, 1)

    model.add(Conv2D(filters = 6, kernel_size = (5, 5), kernel_regularizer = l2(l2_reg)))
    model.add(Activation("relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Dropout(dropout))

    model.add(Conv2D(filters = 16, kernel_size = (5, 5), kernel_regularizer = l2(l2_reg)))
    model.add(Activation("relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Dropout(dropout))

    model.add(Flatten())
    model.add(Dense(120, kernel_regularizer = l2(l2_reg)))
    model.add(Activation("relu"))

    model.add(Dropout(dropout))

    model.add(Dense(84, kernel_regularizer = l2(l2_reg)))
    model.add(Activation("relu"))

    model.add(Dropout(dropout))

    model.add(Dense(num_classes, kernel_regularizer = l2(l2_reg)))
    model.add(Activation("softmax"))
    
    return model

# %%
# LetNet5 model is built using the function LeNet5()
"""
dropout : Intialize the dropout rate for all the Dropout layers.
l2_reg : Initialize L2 regularizer for Conv2D layers and Dense layers.
"""
model = LeNet5(dropout=dropout_rate, l2_reg=l2_reg_rate)

# model.summary() will display a summary for your model (layers name, number of parameters...) to make
# sure you have created the model you want. 
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\hugop\Desktop\Cours\Année 5\Modelisation\TDP\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From C:\Users\hugop\Desktop\Cours\Année 5\Modelisation\TDP\venv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 6)         156
#
#  activation (Activation)     (None, 24, 24, 6)         0
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 6)         0
#  D)
#
#  dropout (Dropout)           (None, 12, 12, 6)         0
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          2416
#
#  activation_1 (Activation)   (None, 8, 8, 16)          0
#
#  max_pooling2d_1 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 16)          0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 120)               30840
#
#  activation_2 (Activation)   (None, 120)               0
#
#  dropout_2 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  activation_3 (Activation)   (None, 84)                0
#
#  dropout_3 (Dropout)         (None, 84)                0
#
#  dense_2 (Dense)             (None, 10)                850
#
#  activation_4 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Optimizer and loss function
#
# In the following cell, we:
# - define the loss function for our Model which is the Crossentropy function.
# - initialize the Gradient Descent Optimizer "SGD".
# - configure the model before training. We use for that "model.compile(...)"
#
# Here, metrics allows to define which is/are the function(s) used to evaluate the model performence during training and testing (accuracy, IoU, loss, ...). For example: metrics = ["accuracy"]

# %%
loss = "SparseCategoricalCrossentropy"

opt = SGD(learning_rate=learning_rate)

model.compile(optimizer=opt, loss = loss, metrics = ["accuracy"])

# %% [markdown]
# # Model training
#
# Now that our model is ready, we can start learning using the function "model.fit".
#
# First, we have to shuffle our training data (shuffle = True).
#
# You can notice that the performance change at the end of each epoch (train loss, train Accuracy, val loss, val accuracy)
#
# => Analyze the parameters of the function "model.fit". The output of this funtion is deeply analyzed in the next cell.

# %%
h = model.fit(x_train, y_train, epochs = epochs, batch_size=batch_size, validation_data = (x_val, y_val), shuffle = True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\hugop\Desktop\Cours\Année 5\Modelisation\TDP\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\hugop\Desktop\Cours\Année 5\Modelisation\TDP\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 375/375 [==============================] - 4s 7ms/step - loss: 0.4510 - accuracy: 0.8637 - val_loss: 0.1508 - val_accuracy: 0.9613
# Epoch 2/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1302 - accuracy: 0.9703 - val_loss: 0.1051 - val_accuracy: 0.9761
# Epoch 3/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1046 - accuracy: 0.9766 - val_loss: 0.1001 - val_accuracy: 0.9789
# Epoch 4/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0889 - accuracy: 0.9821 - val_loss: 0.0987 - val_accuracy: 0.9788
# Epoch 5/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0795 - accuracy: 0.9852 - val_loss: 0.0959 - val_accuracy: 0.9793
# Epoch 6/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0724 - accuracy: 0.9873 - val_loss: 0.0864 - val_accuracy: 0.9837
# Epoch 7/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0679 - accuracy: 0.9886 - val_loss: 0.0798 - val_accuracy: 0.9863
# Epoch 8/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0628 - accuracy: 0.9903 - val_loss: 0.0880 - val_accuracy: 0.9837
# Epoch 9/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0589 - accuracy: 0.9913 - val_loss: 0.0895 - val_accuracy: 0.9829
# Epoch 10/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0567 - accuracy: 0.9921 - val_loss: 0.0796 - val_accuracy: 0.9862
# Epoch 11/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0549 - accuracy: 0.9928 - val_loss: 0.0785 - val_accuracy: 0.9867
# Epoch 12/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0517 - accuracy: 0.9937 - val_loss: 0.0738 - val_accuracy: 0.9883
# Epoch 13/20
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0493 - accuracy: 0.9949 - val_loss: 0.0751 - val_accuracy: 0.9879
# Epoch 14/20
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0473 - accuracy: 0.9952 - val_loss: 0.0792 - val_accuracy: 0.9867
# Epoch 15/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0451 - accuracy: 0.9960 - val_loss: 0.0783 - val_accuracy: 0.9879
# Epoch 16/20
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0442 - accuracy: 0.9960 - val_loss: 0.0802 - val_accuracy: 0.9872
# Epoch 17/20
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0444 - accuracy: 0.9961 - val_loss: 0.0758 - val_accuracy: 0.9883
# Epoch 18/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0419 - accuracy: 0.9968 - val_loss: 0.0848 - val_accuracy: 0.9864
# Epoch 19/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0410 - accuracy: 0.9970 - val_loss: 0.0753 - val_accuracy: 0.9887
# Epoch 20/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0401 - accuracy: 0.9976 - val_loss: 0.0756 - val_accuracy: 0.9887

# %% [markdown]
# # 5. Display the Training & Validation plots
#
# Let's analyze the logs of training.
#
# Here, we plot train and validation accuracy during traning.
#
# We also plot the loss w.r.t. epochs.

# %%
plt.figure(figsize=(12, 5))
plt.plot(h.history["accuracy"], label = "train_acc")
plt.plot(h.history["val_accuracy"], label = "val_acc")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Accuracy", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.figure(figsize=(12, 5))
plt.plot(h.history["loss"], label = "train_loss")
plt.plot(h.history["val_loss"], label = "val_loss")
plt.xlabel("Epochs", fontsize = 12)
plt.ylabel("Loss", fontsize = 12)
plt.xticks(range(epochs))
plt.legend()

plt.show()

# %% [markdown]
# # Evaluation on the test set
#
# The funtion "model.evaluate" can be used to evaluate the performance of the model on the testset.

# %%
print("Model evaluation...")
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# Model evaluation...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0653 - accuracy: 0.9894

# %% [markdown]
# # Trained Model Evaluation:
#
#
# Display few outputs of the trained model by randomly sampling images from x_test. If the prediction is not correct it will be highlited in different color (red)

# %%
display = 64 #choose squares number [9, 16, 25, 36 ...]
samples = sample(range(10000), display) 

sampled_images = x_test[samples]  #sampling 25 random images from the test-set
sampled_labels = y_test[samples]  #sampling their corresponding labels

fig_train = plt.figure(figsize = (17, 17))

rows = int(display**0.5)
cols = int(display**0.5)
for i, (img, y_true) in enumerate(zip(sampled_images, sampled_labels)):
  
    ax = fig_train.add_subplot(rows, cols, i + 1)

    y_pred = model(np.expand_dims(img, 0), training = False)
    y_pred = np.argmax(y_pred)
    if y_pred == y_true:
      ax.set_xlabel("Prediction :{}, True: {}".format(y_pred, y_true), fontsize = 10, color = "k")
    else:
      ax.set_xlabel("Prediction :{}, True: {}".format(y_pred, y_true), fontsize = 10, color = "r")
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(img.squeeze(), cmap = 'gray')

plt.show()

# %% [markdown]
# # Learning rate decay functions
#
# The following functions correspond to different learning rate scheduler:
#
# 1. step_decay : step-based learning rate decay. The initial learning rate is divided after performing several epochs.
# 2. exo_decay : exponential-based learning rate decay. The learning rate value will follow the expontial form starting from the initial value.
#
#
# Example of different Schedulers :
#
#
# ![Alt text](lr_scheduler.png)

# %%
#Step decay
def step_decay(epoch):

    lr = learning_rate
    if epoch >= 24:
        lr = lr * lr_decay**3
    elif epoch >= 16:
        lr = lr * lr_decay**2
    elif epoch >= 8:
        lr = lr * lr_decay**1

    return lr

#Exponential decay
def exp_decay(epoch):

    lr = learning_rate * np.exp(-lr_decay * epoch)

    return lr

# %% [markdown]
# # To do: Provide a description of the code and the dataset

# %% [markdown]
# ### Dataset
#
# Our dataset is composed of pictures of different handwritten numbers.
#
# #### Objective
# Our goal is to make an algorithm able to guess which number is written, whatever how well or bad is it written.
#
# ### How the code works ?
# #### Step 1: Getting our data
# Our data is easy to get thanks to tenserflow (from tensorflow.keras.datasets import mnist).
# We then have to prepare our dataset, separating what have to be used in train and test.
#
# #### Step 2: Preprocessing
# We normalize pixels so that instead of being between 0 and 255 we reduce to 0-1.
# Since TensorFlow needs 3D image, we add a dimension.
#
# #### Step 3: Hyperparameters
# To prepare our model, we need to setup our Hyperparameters.
#
# #### Step 4: Building the CNN model
# The function LeNet5 is actually the main function of the code: This function create the model: 2 Convutional layers and then two dense layers with respectively 120 and 84 neurons and ReLU activation function
# We then add the loss function and optimizer to be able to evaluate our model.
# Finally, we train the model.
#
# #### Step 5: Apply on the test set
# We now have to see if our model is efficient on our test data. After the evaluation we get a little result of 0.9894 accuracy.
# To have an idea of what he has mistaken, we display the pictures.
# And finally, the last block is used to define to decay function (step and exponential) by multiplying the learning rate by a certain value of decay depending on the epoch

# %% [markdown]
# # 6. Grid Search
#
# In the cell below, you will be able to train multiple models, each one with a specific configuration of hyperparameters and functions.
#
# Notice that this process will take few ~Hours depending on the performence of your machine and the total number of combinations.
#
# You can add or change the parameters directly from the for loops.
#
# Using the following config, the total number of combinations is 32.
#
# Feel free to modify or add other hyperparameters to see the impact on the model performence

# %%
history = []

for batch_size in [128, 1024]: #you can try 8, 32...
    for epochs in [30]:
        for learning_rate in [1e-3]:
            for l2_reg in [0, 5e-4]:
                for dropout in [0, 0.4]:
                    for lr_decay in [0.1]: #you can also try 0.01, 0.1, 0.2...
                        for decay_function in [step_decay, exp_decay]:
                            for opt in [Adam(learning_rate=learning_rate), RMSprop(learning_rate=learning_rate)]: #SGD(learning_rate = learning_rate)
                                
                                model_name = "LeNet5-bs{}-ep{}-lr{}-l2reg{}-do{}-lrdec{}-{}-{}".format(batch_size, epochs, learning_rate, l2_reg, dropout, lr_decay,
                                                                                                            "step_decay" if decay_function is step_decay else "exp_decay",
                                                                                                            "Adam" if isinstance(opt, Adam) else "RMSProp" if isinstance(opt, RMSprop) else "SGD")
                                model = LeNet5(l2_reg, dropout)

                                loss = "SparseCategoricalCrossentropy"
                                model.compile(optimizer = opt, loss = loss, metrics = ["accuracy"])

                                lr_scheduler = LearningRateScheduler(decay_function, verbose=0)
                                checkpoint = ModelCheckpoint(filepath="./saved_models/{}.hdf5".format(model_name), save_best_only=True, monitor="val_accuracy", verbose=0)
                                tensorboard = TensorBoard("./logdir/{}".format(model_name))
                                callbacks = [lr_scheduler, checkpoint, tensorboard]
                                
                                print("Start Training for {} epochs".format(epochs))
                                h = model.fit(x_train, y_train, epochs = epochs, batch_size=batch_size, validation_data = (x_val, y_val), shuffle = True, callbacks = callbacks, verbose = 0)
                                history.append(h)
                                print("End of training", model_name)
                                print("Evaluation of the best checkpoint...")
                                model = load_model("./saved_models/{}.hdf5".format(model_name))
                                loss, accuracy = model.evaluate(x_test, y_test)
                                print("\n")
# Out:
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0328 - accuracy: 0.9894
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0293 - accuracy: 0.9910
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0420 - accuracy: 0.9884
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0364 - accuracy: 0.9895
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0485 - accuracy: 0.9853
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0500 - accuracy: 0.9857
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0445 - accuracy: 0.9860
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0479 - accuracy: 0.9858
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0892 - accuracy: 0.9914
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0837 - accuracy: 0.9905
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0816 - accuracy: 0.9907
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0781 - accuracy: 0.9911
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1392 - accuracy: 0.9838
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1403 - accuracy: 0.9840
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1257 - accuracy: 0.9847
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1295 - accuracy: 0.9841
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0579 - accuracy: 0.9810
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0561 - accuracy: 0.9808
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0462 - accuracy: 0.9844
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0407 - accuracy: 0.9866
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0955 - accuracy: 0.9715
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1016 - accuracy: 0.9695
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0911 - accuracy: 0.9724
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0-do0.4-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0771 - accuracy: 0.9768
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1610 - accuracy: 0.9826
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1609 - accuracy: 0.9836
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1683 - accuracy: 0.9803
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1508 - accuracy: 0.9857
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2087 - accuracy: 0.9721
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2220 - accuracy: 0.9682
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1963 - accuracy: 0.9720
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs1024-ep30-lr0.001-l2reg0.0005-do0.4-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1875 - accuracy: 0.9775

# %% [markdown]
# # Which model is the best? Visualizing metrics with TensorBoard:
#
# For better visualization, you need to open the training plots using tensorboard as following:
#
#
# - Make sure that tensorboard is already installed in your machine, otherwise run the following command : pip install tensorboard
#
#
# 1. Open the Command Prompt CMD on the current directory
# 2. Run the command : tensorboard --logdir ./logdir
# 3. Wait few seconds... Then copy the given adress (http://localhost:XXXX/)
# 4. Open your browser (Google Chrome) and past the adress on the adress bar
# 5. Take a look on the different plots, each one has the name of the corresponding model
# 6. Comment the results
#
#
# - For those who use colab, run the following commands on the notebook cells :
#
# 1. %load_ext tensorboard
# 2. %tensorboard --logdir directory/to/logs
#
# Notes:
#
# 1. You can download the logs on your pc instead of opening TensorBoard on colab
# 2. You can open tensorboard monitor during the training without waiting until the end of process (Refresh your browser to update the plots)

# %% [markdown]
# With an accuracy of 99.14% on the test dataset, our top model is: LeNet5-bs128-ep30-lr0.001-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
#
# Here are the hyperparameters which have been used:
# - batch_size: 128
# - decay function: step_decay
# - dropout: 0 (no need since no overfitting has been spotted)
# - epoches: 30
# - learning rate: 0.001
# - l2 regularization: 0.0005
# - learning rate decay: 0.1
# - optimizer: Adam
#
# TensorBoard indicate an accuracy of 99.58% on the training data set, and on the validation set of 98.82%.

# %% [markdown]
# # Add more options in the grid search in order to further improve the result

# %%
history = []

for batch_size in [512]: 
    for epochs in [30]:
        for learning_rate in [1e-2]:
            for l2_reg in [5e-4]:
                for dropout in [0]:
                    for lr_decay in [0.1]: #you can also try 0.01, 0.1, 0.2...
                        for decay_function in [step_decay, exp_decay]:
                            for opt in [Adam(learning_rate=learning_rate), RMSprop(learning_rate=learning_rate)]: #SGD(learning_rate = learning_rate)
                                
                                model_name = "LeNet5-bs{}-ep{}-lr{}-l2reg{}-do{}-lrdec{}-{}-{}".format(batch_size, epochs, learning_rate, l2_reg, dropout, lr_decay,
                                                                                                            "step_decay" if decay_function is step_decay else "exp_decay",
                                                                                                            "Adam" if isinstance(opt, Adam) else "RMSProp" if isinstance(opt, RMSprop) else "SGD")
                                model = LeNet5(l2_reg, dropout)

                                loss = "SparseCategoricalCrossentropy"
                                model.compile(optimizer = opt, loss = loss, metrics = ["accuracy"])

                                lr_scheduler = LearningRateScheduler(decay_function, verbose=0)
                                checkpoint = ModelCheckpoint(filepath="./saved_models/{}.hdf5".format(model_name), save_best_only=True, monitor="val_accuracy", verbose=0)
                                tensorboard = TensorBoard("./logdir/{}".format(model_name))
                                callbacks = [lr_scheduler, checkpoint, tensorboard]
                                
                                print("Start Training for {} epochs".format(epochs))
                                h = model.fit(x_train, y_train, epochs = epochs, batch_size=batch_size, validation_data = (x_val, y_val), shuffle = True, callbacks = callbacks, verbose = 0)
                                history.append(h)
                                print("End of training", model_name)
                                print("Evaluation of the best checkpoint...")
                                model = load_model("./saved_models/{}.hdf5".format(model_name))
                                loss, accuracy = model.evaluate(x_test, y_test)
                                print("\n")
# Out:
# Start Training for 30 epochs
# End of training LeNet5-bs512-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0733 - accuracy: 0.9916
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs512-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0830 - accuracy: 0.9904
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs512-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-exp_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0712 - accuracy: 0.9916
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs512-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-exp_decay-RMSProp
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0744 - accuracy: 0.9911

# %%
history = []
accuracy = 0
while accuracy<0.9920: #Let it reshuffle until the algorithm have a better mulligan
    
    for batch_size in [256]:
        for epochs in [30]:
            for learning_rate in [1e-2]:
                for l2_reg in [5e-4]:
                    for dropout in [0]:
                        for lr_decay in [0.1]: #you can also try 0.01, 0.1, 0.2...
                            for decay_function in [step_decay]:
                                for opt in [Adam(learning_rate=learning_rate)]: #Adam has given us the best result before, so we keep Adam only.

                                    model_name = "LeNet5-bs{}-ep{}-lr{}-l2reg{}-do{}-lrdec{}-{}-{}".format(batch_size, epochs, learning_rate, l2_reg, dropout, lr_decay,
                                                                                                                "step_decay" if decay_function is step_decay else "exp_decay",
                                                                                                                "Adam" if isinstance(opt, Adam) else "RMSProp" if isinstance(opt, RMSprop) else "SGD")
                                    model = LeNet5(l2_reg, dropout)

                                    loss = "SparseCategoricalCrossentropy"
                                    model.compile(optimizer = opt, loss = loss, metrics = ["accuracy"])

                                    lr_scheduler = LearningRateScheduler(decay_function, verbose=0)
                                    checkpoint = ModelCheckpoint(filepath="./saved_models/{}.hdf5".format(model_name), save_best_only=True, monitor="val_accuracy", verbose=0)
                                    tensorboard = TensorBoard("./logdir/{}".format(model_name))
                                    callbacks = [lr_scheduler, checkpoint, tensorboard]

                                    print("Start Training for {} epochs".format(epochs))
                                    h = model.fit(x_train, y_train, epochs = epochs, batch_size=batch_size, validation_data = (x_val, y_val), shuffle = True, callbacks = callbacks, verbose = 0)
                                    history.append(h)
                                    print("End of training", model_name)
                                    print("Evaluation of the best checkpoint...")
                                    model = load_model("./saved_models/{}.hdf5".format(model_name))
                                    loss, accuracy = model.evaluate(x_test, y_test)
                                    print("\n")
# Out:
# Start Training for 30 epochs
# End of training LeNet5-bs256-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0744 - accuracy: 0.9914
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs256-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0720 - accuracy: 0.9917
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs256-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0734 - accuracy: 0.9910
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs256-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0750 - accuracy: 0.9906
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs256-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0857 - accuracy: 0.9917
#
#
# Start Training for 30 epochs
# End of training LeNet5-bs256-ep30-lr0.01-l2reg0.0005-do0-lrdec0.1-step_decay-Adam
# Evaluation of the best checkpoint...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0736 - accuracy: 0.9921

# %% [markdown]
# By changing some of the hyperparameters and some iterations, we get at best the following result:
#
# Accuracy on test data set : 0.9921
#
# Here are the hyperparameters of our model:
# - batch_size: 256
# - decay function: step_decay
# - dropout: 0
# - epoches: 30
# - learning rate: 0.01
# - l2 regularization: 0.0005
# - learning rate decay: 0.1
# - optimizer: Adam
#
# TensorBoard view:
#
# Accuracy on the train set : 0.9972
# Accuracy on the validation set : 0.9910

# %% [markdown]
# After further testing, the school's computer being much more powerful than my own, we've gotten 0.9929 at best. TO improve the result, maybe adding a little dropout was interesting even tho we didn't notice much overfitting during the test.
